# %% [markdown]
# # RAG con PDFs (Notebook paralelo)
# Este cuaderno replica el flujo de `rag_cli.py` pero muestra cada etapa con resúmenes y estadísticas para entender los datos procesados.

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: python-dotenv in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (1.2.1)
# Requirement already satisfied: openai in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (2.8.1)
# Requirement already satisfied: langchain in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: langchain-openai in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: langchain-community in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: langchain-core in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: langchainhub in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (0.1.21)
# Requirement already satisfied: langchain-qdrant in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: langchain-text-splitters in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: langchain-experimental in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: langgraph in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (1.0.3)
# Requirement already satisfied: langsmith in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (0.4.47)
# Requirement already satisfied: pypdf in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (6.5.0)
# Requirement already satisfied: qdrant-client in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (1.16.2)
# Requirement already satisfied: faiss-cpu in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (1.13.1)
# Requirement already satisfied: tiktoken in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (0.12.0)
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (2.3.5)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (2.3.3)
# Requirement already satisfied: scikit-learn in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (1.8.0)
# Requirement already satisfied: plotly in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (6.5.0)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 22)) (3.10.8)
# Requirement already satisfied: umap-learn in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (0.5.9.post2)
# Requirement already satisfied: ipywidgets in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 24)) (8.1.8)
# Requirement already satisfied: tqdm in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 25)) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 26)) (4.14.3)
# Requirement already satisfied: openpyxl in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (3.1.5)
# Requirement already satisfied: nbformat in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (5.10.4)
# Requirement already satisfied: nest-asyncio in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from -r requirements.txt (line 29)) (1.6.0)
# Requirement already satisfied: pydantic in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (2.12.4)
# Requirement already satisfied: fastapi in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 31)) (0.127.0)
# Requirement already satisfied: uvicorn in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 32)) (0.40.0)
# Requirement already satisfied: langserve[server] in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (0.3.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/lib/python3.11/site-packages (from openai->-r requirements.txt (line 3)) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from openai->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from openai->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/homebrew/lib/python3.11/site-packages (from openai->-r requirements.txt (line 3)) (0.12.0)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from openai->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from openai->-r requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic->-r requirements.txt (line 30)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/homebrew/lib/python3.11/site-packages (from pydantic->-r requirements.txt (line 30)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/homebrew/lib/python3.11/site-packages (from pydantic->-r requirements.txt (line 30)) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 3)) (3.11)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core->-r requirements.txt (line 7)) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core->-r requirements.txt (line 7)) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core->-r requirements.txt (line 7)) (9.1.2)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /opt/homebrew/lib/python3.11/site-packages (from langgraph->-r requirements.txt (line 12)) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /opt/homebrew/lib/python3.11/site-packages (from langgraph->-r requirements.txt (line 12)) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /opt/homebrew/lib/python3.11/site-packages (from langgraph->-r requirements.txt (line 12)) (0.2.10)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/homebrew/lib/python3.11/site-packages (from langgraph->-r requirements.txt (line 12)) (3.6.0)
# Requirement already satisfied: orjson>=3.9.14 in /opt/homebrew/lib/python3.11/site-packages (from langsmith->-r requirements.txt (line 13)) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith->-r requirements.txt (line 13)) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith->-r requirements.txt (line 13)) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith->-r requirements.txt (line 13)) (0.25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/homebrew/lib/python3.11/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph->-r requirements.txt (line 12)) (1.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/homebrew/lib/python3.11/site-packages (from tiktoken->-r requirements.txt (line 17)) (2025.11.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community->-r requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community->-r requirements.txt (line 6)) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community->-r requirements.txt (line 6)) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community->-r requirements.txt (line 6)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community->-r requirements.txt (line 6)) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community->-r requirements.txt (line 6)) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 6)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 6)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 6)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 6)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 6)) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirements.txt (line 6)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirements.txt (line 6)) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.0.0->langsmith->-r requirements.txt (line 13)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests>=2.0.0->langsmith->-r requirements.txt (line 13)) (2.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /opt/homebrew/lib/python3.11/site-packages (from langchainhub->-r requirements.txt (line 8)) (2.32.4.20250913)
# Requirement already satisfied: grpcio>=1.41.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client->-r requirements.txt (line 15)) (1.76.0)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client->-r requirements.txt (line 15)) (3.2.0)
# Requirement already satisfied: protobuf>=3.20.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client->-r requirements.txt (line 15)) (6.33.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from pandas->-r requirements.txt (line 19)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 19)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 19)) (2025.2)
# Requirement already satisfied: scipy>=1.10.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 20)) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 20)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/homebrew/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 20)) (3.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/homebrew/lib/python3.11/site-packages (from plotly->-r requirements.txt (line 21)) (2.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 22)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 22)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 22)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 22)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 22)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 22)) (3.3.1)
# Requirement already satisfied: numba>=0.51.2 in /opt/homebrew/lib/python3.11/site-packages (from umap-learn->-r requirements.txt (line 23)) (0.63.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from umap-learn->-r requirements.txt (line 23)) (0.5.13)
# Requirement already satisfied: comm>=0.1.3 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipywidgets->-r requirements.txt (line 24)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipywidgets->-r requirements.txt (line 24)) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipywidgets->-r requirements.txt (line 24)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets->-r requirements.txt (line 24)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /opt/homebrew/lib/python3.11/site-packages (from ipywidgets->-r requirements.txt (line 24)) (3.0.16)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/homebrew/lib/python3.11/site-packages (from beautifulsoup4->-r requirements.txt (line 26)) (2.8.1)
# Requirement already satisfied: et-xmlfile in /opt/homebrew/lib/python3.11/site-packages (from openpyxl->-r requirements.txt (line 27)) (2.0.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/homebrew/lib/python3.11/site-packages (from nbformat->-r requirements.txt (line 28)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/homebrew/lib/python3.11/site-packages (from nbformat->-r requirements.txt (line 28)) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from nbformat->-r requirements.txt (line 28)) (5.9.1)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /opt/homebrew/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 31)) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/homebrew/lib/python3.11/site-packages (from fastapi->-r requirements.txt (line 31)) (0.0.4)
# Requirement already satisfied: click>=7.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn->-r requirements.txt (line 32)) (8.3.1)
# Requirement already satisfied: sse-starlette<2.0.0,>=1.3.0 in /opt/homebrew/lib/python3.11/site-packages (from langserve[server]->-r requirements.txt (line 33)) (1.8.2)
# Requirement already satisfied: h2<5,>=3 in /opt/homebrew/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 15)) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/homebrew/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 15)) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/homebrew/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client->-r requirements.txt (line 15)) (4.1.0)
# Requirement already satisfied: decorator>=4.3.2 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (0.8.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 28)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 28)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/homebrew/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 28)) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->-r requirements.txt (line 28)) (4.5.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /opt/homebrew/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn->-r requirements.txt (line 23)) (0.46.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 19)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/fabiansalfatenavarro/Library/Python/3.11/lib/python/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 24)) (0.2.3)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import pandas as pd
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_experimental.text_splitter import SemanticChunker
from rag_modulo3 import (
    PDF_DIR,
    COLLECTION_NAME,
)
from rag_modulo3.preparation import (
    load_pdf_documents,
    extract_metadata,
    chunk_documents,
    build_vector_store,
)
from rag_modulo3.rag_chain import (
    build_query_rewriter,
    answer_question,
)

load_dotenv()
print(f"📁 Directorio de PDFs: {PDF_DIR.resolve()}")
print(f"📚 Colección en uso: {COLLECTION_NAME}")
# Out:
# 📁 Directorio de PDFs: /Users/fabiansalfatenavarro/Desktop/Diplomando IA/Archivos/M3/Tarea Grupal/pdf
# 📚 Colección en uso: rag_mod3_pdf_exportaciones

# %% [markdown]
# ## Inventario de PDFs

# %%
pdf_records = []
for path in sorted(PDF_DIR.glob('*.pdf')):
    stat = path.stat()
    pdf_records.append({
        "archivo": path.name,
        "tam_mb": round(stat.st_size / 1e6, 2),
        "modificado": stat.st_mtime,
    })

pdf_df = pd.DataFrame(pdf_records)
if pdf_df.empty:
    raise RuntimeError("No hay PDFs en la carpeta pdf/.")
pdf_df
# Out:
#                                              archivo  tam_mb    modificado
# 0  Claves-para-hacer-negocios-con-Singapur-2025 v...    7.58  1.766718e+09
# 1  Claves_para_hacer_negocios_Emiratos-Arabes-Uni...    7.36  1.766718e+09
# 2      Claves_para_hacer_negocios_Espana_2025 v2.pdf    9.01  1.766718e+09
# 3  Estudio-Claves-para-hacer-negocios-con-Japon-2...    5.43  1.766718e+09
# 4                 NoCobre_NoLitio_noviembre-1 v2.pdf    5.82  1.766718e+09

# %% [markdown]
# ## 1. Carga completa de documentos

# %%
raw_documents = load_pdf_documents()
print(f"Documentos cargados: {len(raw_documents)}")
print("\nEjemplo de metadata base:")
print(raw_documents[0].metadata)
print("\nFragmento del contenido:\n", raw_documents[0].page_content[:500])
# Out:
# Documentos cargados: 5
#
# Ejemplo de metadata base:
# {'source': 'pdf/Claves-para-hacer-negocios-con-Singapur-2025 v2.pdf'}
#
# Fragmento del contenido:
#  3¡
# ProChile” ssssssssssssssssssssssssssssssss
# *x HACIENDO
# NEGOCIOS CON EL MUNDO
# AÑOS ¢
# Claves para
# hacer negocios con
# Singapur| 2025
# Oficina Comercial de ProChile en Kuala Lumpur, Malasia
# ProChile - Todos los derechos reservados.
# Marzo, 2025
#
# Claves para hacer negocios con Singapur| 2025
# 1. Singapur como mercado
# La isla de Singapur se encuentra a 137 Km al norte del
# ecuador. Está formado por 64 islas incluyendo la isla
# principal conocida como la isla de Singapur o Pulau
# Ujong.
# La

# %% [markdown]
# ## 2. Extracción de metadata con GPT-4o

# %%
llm = ChatOpenAI(model='gpt-4o', temperature=0.1)
metadata_map = extract_metadata(raw_documents, llm)
metadata_df = pd.DataFrame([
    {
        'source': src,
        'titulo': meta.titulo,
        'categoria': meta.categoria,
        'resumen': meta.resumen,
    }
    for src, meta in metadata_map.items()
])
metadata_df
# Out:
#                                               source  \
# 0  pdf/Claves-para-hacer-negocios-con-Singapur-20...
# 1  pdf/Claves_para_hacer_negocios_Emiratos-Arabes...
# 2  pdf/Claves_para_hacer_negocios_Espana_2025 v2.pdf
# 3  pdf/Estudio-Claves-para-hacer-negocios-con-Jap...
# 4             pdf/NoCobre_NoLitio_noviembre-1 v2.pdf
#
#                                           titulo  \
# 0              Guía de Negocios en Singapur 2025
# 1        Claves para el Éxito Empresarial en EAU
# 2  Claves para Hacer Negocios con España en 2025
# 3                 Claves para Negocios con Japón
# 4        Análisis de Exportaciones Chilenas 2025
#
#                       categoria  \
# 0      Negocios Internacionales
# 1      Negocios Internacionales
# 2      Negocios Internacionales
# 3      Negocios Internacionales
# 4  Economía y Comercio Exterior
#
#                                              resumen
# 0  Singapur es un centro financiero y comercial e...
# 1  Los empresarios en Emiratos Árabes Unidos dest...
# 2  El documento explora las tendencias clave del ...
# 3  El documento destaca la prudencia del empresar...
# 4  El informe de ProChile analiza las exportacion...

# %% [markdown]
# ## 3. Semantic chunking y estadísticas

# %%
chunk_embeddings = OpenAIEmbeddings(model='text-embedding-3-large')
chunker = SemanticChunker(
    chunk_embeddings,
    breakpoint_threshold_type='percentile',
    breakpoint_threshold_amount=50,
)
chunked_docs = chunk_documents(raw_documents, metadata_map, chunker)
print(f"Chunks generados: {len(chunked_docs)}")

stats_df = pd.DataFrame([
    {
        'titulo': doc.metadata.get('titulo', 'N/A'),
        'source': doc.metadata.get('source'),
        'chars': len(doc.page_content),
        'words': len(doc.page_content.split()),
    }
    for doc in chunked_docs
])
print("\nResumen por documento:")
stats_summary = stats_df.groupby(['titulo']).agg(
    chunks=('source', 'count'),
    palabras_promedio=('words', 'mean'),
)
stats_summary
# Out:
# Chunks generados: 440
#
# Resumen por documento:
#                                                chunks  palabras_promedio
# titulo
# Análisis de Exportaciones Chilenas 2025            37          81.972973
# Claves para Hacer Negocios con España en 2025     146          40.993151
# Claves para Negocios con Japón                     76          56.276316
# Claves para el Éxito Empresarial en EAU           113          50.548673
# Guía de Negocios en Singapur 2025                  68          47.941176

# %% [markdown]
# ## 4. Creación / actualización del vector store en Qdrant

# %%
vector_store = build_vector_store(chunked_docs)
print('Vector store actualizado en Qdrant. Colección:', vector_store.collection_name)
# Out:
# Vector store actualizado en Qdrant. Colección: rag_mod3_pdf_exportaciones

# %% [markdown]
# ### Estado de la colección en Qdrant

# %%
from rag_modulo3 import COLLECTION_NAME, get_qdrant_client

client = get_qdrant_client()
collection = client.get_collection(COLLECTION_NAME)
params = collection.config.params
vector_size = None
if hasattr(params, "vectors") and isinstance(params.vectors, dict):
    default_vec = params.vectors.get("")
    if default_vec is not None:
        vector_size = getattr(default_vec, "size", None)
elif isinstance(params, dict):
    vectors = params.get("vectors", {})
    if isinstance(vectors, dict):
        default_vec = vectors.get("")
        if isinstance(default_vec, dict):
            vector_size = default_vec.get("size")

print(f"Colección analizada: {COLLECTION_NAME}")
print("Vectores indexados:", collection.points_count)
print("Dimensiones:", vector_size)
# Out:
# Colección analizada: rag_mod3_pdf_exportaciones
# Vectores indexados: 718
# Dimensiones: 3072

# %% [markdown]
# ## 5. Consulta de ejemplo con reescritura

# %%
# Después de crear el vector_store:
retriever = vector_store.as_retriever(search_kwargs={"k": 5})

rewrite_chain = build_query_rewriter(llm)
demo_query = "¿Qué oportunidades comerciales hay para exportar servicios en 2025?"
response = answer_question(demo_query, retriever, llm, rewrite_chain)
print(response)
# Out:
# En 2025, las oportunidades para exportar servicios desde Chile se presentan principalmente en sectores que han mostrado un crecimiento significativo. Según el "Análisis de Exportaciones Chilenas 2025", los servicios de Tecnologías de la Información y Comunicación (TICs) lideran con un valor FOB de US$ 909 millones y un crecimiento del 2,7%. Otros sectores destacados incluyen los servicios financieros, con un crecimiento del 4,4%, y los servicios de administración, que crecieron un 3,5% (Fuente: Análisis de Exportaciones Chilenas 2025).
#
# Además, el "Manual de Exportación de Servicios" sugiere que la diversificación de la oferta exportable hacia servicios de alto valor agregado es una estrategia viable para integrarse en cadenas globales de valor. Esto implica que sectores como la investigación y desarrollo, la asesoría, y los servicios logísticos también presentan oportunidades significativas para la exportación (Fuente: Guía para la Exportación de Servicios).
#
# En términos de mercados, Estados Unidos, Perú y Colombia son los principales destinos para los servicios chilenos, lo que indica una oportunidad para expandir la presencia en estos países (Fuente: Análisis de Exportaciones Chilenas 2025).
#
# En resumen, las oportunidades para exportar servicios en 2025 se centran en sectores tecnológicos y financieros, con un enfoque en la diversificación y la integración en mercados internacionales clave.
#
# Fuentes consultadas:
# - Análisis de Exportaciones Chilenas 2025 (pdf/NoCobre_NoLitio_noviembre-1.pdf)
# - Guía para la Exportación de Servicios (pdf/Manual-de-Exportacion-de-Servicios-2025.pdf)
# - Guía para la Exportación de Servicios (pdf/Manual-de-Exportacion-de-Servicios-2025.pdf)
# - Guía para la Exportación de Servicios (pdf/Manual-de-Exportacion-de-Servicios-2025.pdf)
# - Guía para la Exportación de Servicios (pdf/Manual-de-Exportacion-de-Servicios-2025.pdf)

# %%
from rag_modulo3.config import load_environment, COLLECTION_NAME
from rag_modulo3.rag_chain import load_vector_store
from langchain_openai import OpenAIEmbeddings

load_environment()
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
vector_store = load_vector_store(embeddings)

def max_score(query):
    results = vector_store.similarity_search_with_relevance_scores(query, k=3)
    return [(doc.metadata.get("titulo"), score) for doc, score in results]

print(max_score("Información de España"))
print(max_score("Información de Chile"))
print(max_score("Constitución de Estados Unidos"))
print(max_score("Información de Japon"))
print(max_score("Información de PlayStation 5"))
# Out:
# [('Claves para Hacer Negocios con España en 2025', 0.754091025), ('Claves para Hacer Negocios con España en 2025', 0.74984123), ('Claves para Hacer Negocios con España en 2025', 0.74843865)]
# [('Claves para el Éxito Empresarial en EAU', 0.78993702), ('Análisis de Exportaciones Chilenas sin Cobre ni Litio', 0.77982365), ('Guía de Negocios en Singapur 2025', 0.77752585)]
# [('Claves para el Éxito Empresarial en EAU', 0.650950285), ('Claves para Hacer Negocios con España en 2025', 0.6445491), ('Claves para el Éxito Empresarial en EAU', 0.64258033)]
# [('Claves para Negocios con Japón', 0.7773887500000001), ('Claves para Negocios con Japón', 0.756977765), ('Claves para Negocios con Japón', 0.74979019)]
# [('Claves para Negocios con Japón', 0.6643162499999999), ('Claves para Hacer Negocios con España en 2025', 0.6566413799999999), ('Claves para Hacer Negocios con España en 2025', 0.6503548)]
